# %%
import re

# %%
contents = ""
with open("/Users/lusoul/Downloads/CHK_122_060415_070217.QFX", "r") as f:
    contents = f.readlines()
print contents
print type(contents[100])
contents[10].
# Out:
# ['OFXHEADER:100\r\n', 'DATA:OFXSGML\r\n', 'VERSION:102\r\n', 'SECURITY:NONE\r\n', 'ENCODING:USASCII\r\n', 'CHARSET:1252\r\n', 'COMPRESSION:NONE\r\n', 'OLDFILEUID:NONE\r\n', 'NEWFILEUID:NONE\r\n', '\r\n', '<OFX>\r\n', '<SIGNONMSGSRSV1>\r\n', '<SONRS>\r\n', '<STATUS>\r\n', '<CODE>0\r\n', '<SEVERITY>INFO\r\n', '</STATUS>\r\n', '<DTSERVER>20170703063943\r\n', '<LANGUAGE>ENG\r\n', '<FI>\r\n', '<ORG>Citibank\r\n', '<FID>2102\r\n', '</FI>\r\n', '<INTU.BID>2102\r\n', '</SONRS>\r\n', '</SIGNONMSGSRSV1>\r\n', '<BANKMSGSRSV1>\r\n', '<STMTTRNRS>\r\n', '<TRNUID>0\r\n', '<STATUS>\r\n', '<CODE>0\r\n', '<SEVERITY>INFO\r\n', '</STATUS>\r\n', '<STMTRS>\r\n', '<CURDEF>USD\r\n', '<BANKACCTFROM>\r\n', '<BANKID>143456789\r\n', '<ACCTID>XXXXX8122\r\n', '<ACCTTYPE>CHECKING\r\n', '</BANKACCTFROM>\r\n', '<BANKTRANLIST>\r\n', '<DTSTART>20150604\r\n', '<DTEND>20170702210000\r\n', '<STMTTRN>\r\n', '<TRNTYPE>CREDIT\r\n', '<DTPOSTED>20151204120000\r\n', '<TRNAMT>1997.93\r\n', '<FITID>201512040001\r\n', '<NAME>ACH 
# ...

# %%
ret = []
for i in range(len(contents)):
    try:
        contents[i].index("503.30")
        ret.append(contents[i])
    except:
        pass

print ret
print len(ret)
# Out:
# ['<TRNAMT>-503.30\r\n', '<TRNAMT>-503.30\r\n', '<TRNAMT>-503.30\r\n', '<TRNAMT>-503.30\r\n', '<TRNAMT>-503.30\r\n', '<TRNAMT>-503.30\r\n', '<TRNAMT>-503.30\r\n', '<TRNAMT>-503.30\r\n', '<TRNAMT>-503.30\r\n', '<TRNAMT>-503.30\r\n', '<TRNAMT>-503.30\r\n', '<TRNAMT>-503.30\r\n', '<TRNAMT>-503.30\r\n', '<TRNAMT>-503.30\r\n', '<TRNAMT>-503.30\r\n', '<TRNAMT>-503.30\r\n', '<TRNAMT>-503.30\r\n', '<TRNAMT>-503.30\r\n', '<TRNAMT>-503.30\r\n']
# 19
